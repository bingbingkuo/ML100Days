# %% [markdown]
# 作業目標:<br>
# 1. 靈活運用圖表在各種情況下
# 2. 圖表的解讀

# %% [markdown]
# 作業重點:<br>
# 1. 依據需求畫出圖表<br>
# 2. 在做圖表解釋時，須了解圖表中的含意

# %% [markdown]
# 題目 : 將資料夾中boston.csv讀進來，並用圖表分析欄位。<br>
# 1.畫出箱型圖，並判斷哪個欄位的中位數在300~400之間?<br>
# 2.畫出散佈圖 x='NOX', y='DIS' ，並說明這兩欄位有什麼關係?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data=pd.read_csv("boston.csv")

#觀察資料
print("資料數量", data.shape)
print("資料蘭位", data.columns)

#分析資料
print("平均數",data["TAX"].median())

#分析資料
print(data["NOX"])
print(data["DIS"])
# Out:
# 資料數量 (505, 14)
# 資料蘭位 Index(['key', 'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'],
#       dtype='object')
# 平均數 330.0
# 0      0.469
# 1      0.469
# 2      0.458
# 3      0.458
# 4      0.458
#        ...
# 500    0.573
# 501    0.573
# 502    0.573
# 503    0.573
# 504    0.573
# Name: NOX, Length: 505, dtype: float64
# 0      4.9671
# 1      4.9671
# 2      6.0622
# 3      6.0622
# 4      6.0622
#         ...
# 500    2.4786
# 501    2.2875
# 502    2.1675
# 503    2.3889
# 504    2.5050
# Name: DIS, Length: 505, dtype: float64

# %%
#1.畫出箱型圖，並判斷哪個欄位的中位數在300~400之間?

data.boxplot()

# TAX 的中位數在300~400之間
# Out:
# <AxesSubplot:>

# %%
#2. 畫出散佈圖 x='NOX', y='DIS' ，並說明這兩欄位有什麼關係?

x = data["NOX"]
y = data["DIS"]


plt.scatter(x, y, s=50, c="c", alpha=0.5)

plt.show()

#當 X 越大 Y 會越小
#當 Y 越大 X 會越小
#兩者呈反比例的關係
